# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('ccard_data.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
df.shape
# Out:
# (10127, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                       0
# Attrition_Flag                  0
# Customer_Age                    0
# Gender                          0
# Dependent_count                 0
# Education_Level                 0
# Marital_Status                  0
# Income_Category                 0
# Card_Category                   0
# Months_on_book                  0
# Total_Relationship_Count        0
# Months_Inactive_12_mon          0
# Contacts_Count_12_mon           0
# Credit_Limit                    0
# Total_Revolving_Bal             0
# Total_Trans_Amt                 0
# Unnamed: 16                 10127
# dtype: int64

# %%
df.drop(columns = 'Unnamed: 16', axis = 0, inplace = True)

# %%
df.drop_duplicates()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.Credit_Limit = df.Credit_Limit.astype(int)

# %%
df.dtypes
# Out:
# CLIENTNUM                    int64
# Attrition_Flag              object
# Customer_Age                 int64
# Gender                      object
# Dependent_count              int64
# Education_Level             object
# Marital_Status              object
# Income_Category             object
# Card_Category               object
# Months_on_book               int64
# Total_Relationship_Count     int64
# Months_Inactive_12_mon       int64
# Contacts_Count_12_mon        int64
# Credit_Limit                 int32
# Total_Revolving_Bal          int64
# Total_Trans_Amt              int64
# dtype: object

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
df.groupby('Education_Level').size().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Education_Level'>

# %%
sns.histplot(df, x = 'Card_Category')
# Out:
# <AxesSubplot:xlabel='Card_Category', ylabel='Count'>

# %%
df.groupby('Gender').size().plot(kind = 'pie', autopct = '%.1f', ylabel = '', title = 'Gender-wise Distribution')
# Out:
# <AxesSubplot:title={'center':'Gender-wise Distribution'}>

# %%
sns.histplot(df, x = 'Income_Category')
# Out:
# <AxesSubplot:xlabel='Income_Category', ylabel='Count'>

# %%
sns.histplot(df, x = 'Dependent_count')
# Out:
# <AxesSubplot:xlabel='Dependent_count', ylabel='Count'>

# %%
sns.histplot(df, x = 'Attrition_Flag')
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='Count'>

# %%
sns.histplot(df['Customer_Age'], kde = True)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie', autopct = '%.1f', ylabel = '', title = 'Customer Distribution by their Maritial Status')
# Out:
# <AxesSubplot:title={'center':'Customer Distribution by their Maritial Status'}>

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
sns.histplot(df['Months_Inactive_12_mon'])
# Out:
# <AxesSubplot:xlabel='Months_Inactive_12_mon', ylabel='Count'>

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %% [markdown]
# # Churned Customers Analysis

# %%
df.Attrition_Flag.value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
churn_rate = 1627/10127 * 100
print("The customer churn rate is", churn_rate)
# Out:
# The customer churn rate is 16.065962279055988

# %%
churned = df.Attrition_Flag.apply(lambda x: True if x == 'Attrited Customer' else False)

# %%
df[churned]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21     708508758  Attrited Customer            62      F                0
# 39     708300483  Attrited Customer            66      F                0
# 51     779471883  Attrited Customer            54      F                1
# 54     714374133  Attrited Customer            56      M                2
# 61     712030833  Attrited Customer            48      M                2
# ...          ...                ...           ...    ...              ...
# 10119  716893683  Attrited Customer            55      F                3
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
churned_customers = df[churned]

# %%
churned_customers.head()
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21  708508758  Attrited Customer            62      F                0
# 39  708300483  Attrited Customer            66      F                0
# 51  779471883  Attrited Customer            54      F                1
# 54  714374133  Attrited Customer            56      M                2
# 61  712030833  Attrited Customer            48      M                2
#
#    Education_Level Marital_Status Income_Category Card_Category  \
# 21        Graduate        Married  Less than $40K          Blue
# 39       Doctorate        Married         Unknown          Blue
# 51        Graduate        Married  Less than $40K          Blue
# 54        Graduate        Married         $120K +          Blue
# 61        Graduate        Married     $60K - $80K        Silver
#
#     Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 21              49                         2                       3
# ...

# %%
sns.histplot(churned_customers['Education_Level'])
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='Count'>

# %%
sns.histplot(churned_customers['Income_Category'])
# Out:
# <AxesSubplot:xlabel='Income_Category', ylabel='Count'>

# %%
churned_customers.groupby('Marital_Status').size().plot(kind = 'pie', autopct = '%.1f', ylabel = '', title = 'Customer Distribution by their Maritial Status')
# Out:
# <AxesSubplot:title={'center':'Customer Distribution by their Maritial Status'}>

# %%
sns.histplot(churned_customers['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(churned_customers['Customer_Age'])
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
churned_customers.head()
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21  708508758  Attrited Customer            62      F                0
# 39  708300483  Attrited Customer            66      F                0
# 51  779471883  Attrited Customer            54      F                1
# 54  714374133  Attrited Customer            56      M                2
# 61  712030833  Attrited Customer            48      M                2
#
#    Education_Level Marital_Status Income_Category Card_Category  \
# 21        Graduate        Married  Less than $40K          Blue
# 39       Doctorate        Married         Unknown          Blue
# 51        Graduate        Married  Less than $40K          Blue
# 54        Graduate        Married         $120K +          Blue
# 61        Graduate        Married     $60K - $80K        Silver
#
#     Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 21              49                         2                       3
# ...

# %%
sns.boxplot(churned_customers['Credit_Limit'])
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
churned_customers.Credit_Limit.min()
# Out:
# 1438

# %%
churned_customers.Credit_Limit.max()
# Out:
# 34516

# %%
print("10th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 10))
# Out:
# 10th percentile of Credit Limit:  1519.6000000000001

# %%
print("25th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 25))
# Out:
# 25th percentile of Credit Limit:  2114.0

# %%
print("50th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 50))
# Out:
# 50th percentile of Credit Limit:  4178.0

# %%
print("70th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 70))
# Out:
# 70th percentile of Credit Limit:  8299.399999999998

# %%
print("90th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 90))
# Out:
# 90th percentile of Credit Limit:  23244.0

# %%
print("95th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 95))
# Out:
# 95th percentile of Credit Limit:  34516.0

# %%
print("99th percentile of Credit Limit: ", np.percentile(churned_customers['Credit_Limit'], 99))
# Out:
# 99th percentile of Credit Limit:  34516.0

# %%
sns.histplot(churned_customers['Dependent_count'])
# Out:
# <AxesSubplot:xlabel='Dependent_count', ylabel='Count'>

# %%
sns.histplot(churned_customers['Months_Inactive_12_mon'], color = 'blue')
# Out:
# <AxesSubplot:xlabel='Months_Inactive_12_mon', ylabel='Count'>

# %%
sns.histplot(churned_customers['Total_Trans_Amt'], color = 'blue', kde = True)
# Out:
# <AxesSubplot:xlabel='Total_Trans_Amt', ylabel='Count'>

# %%
sns.pairplot(churned_customers)
